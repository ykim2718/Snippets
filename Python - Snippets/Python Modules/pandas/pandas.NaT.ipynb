# %%
import pandas as pd
a = pd.Timestamp('20170711')
a
# Out:
# Timestamp('2017-07-11 00:00:00')

# %%
type(pd.NaT)
# Out:
# pandas.tslib.NaTType

# %%
isinstance(a, type(pd.NaT))
# Out:
# False

# %%
b = pd.Timestamp(None)

# %%
isinstance(b, type(pd.NaT))
# Out:
# True
