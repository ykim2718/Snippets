# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'1': list('abc'), 2: [None, '', np.nan], 3: [4, 5, 6]}, index=list('xyz'))
df
# Out:
#       2  3  1
# x  None  4  a
# y        5  b
# z   NaN  6  c

# %%
~ pd.isnull(df[2])
# Out:
# x    False
# y     True
# z    False
# Name: 2, dtype: bool

# %%
df[['1', 2]].isnull()
# Out:
#        1      2
# x  False   True
# y  False  False
# z  False   True

# %%
df[['1', 2]].notnull()
# Out:
#       1      2
# x  True  False
# y  True   True
# z  True  False

# %%
df[['1', 2]].isnull().any(axis=1)
# Out:
# x     True
# y    False
# z     True
# dtype: bool
